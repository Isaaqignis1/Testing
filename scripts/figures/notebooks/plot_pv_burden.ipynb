# %% [markdown]
# # plot_pv_burden
# Mirror of scripts/figures/plot_pv_burden.py — Figures 1 (scatter) and 2 (boxplot).
#
# The matching .py script under scripts/figures/ is the canonical version. Edit there for the pipeline run; this notebook is just for figure tweaks.

# %%
import os, sys
from pathlib import Path
REPO_ROOT = Path(os.environ.get("REPO_ROOT", Path.cwd().parents[2]))
OUTPUTS   = Path(os.environ.get("OUTPUTS_DIR", REPO_ROOT / "OUTPUTS"))
STANDARDS = REPO_ROOT / "standards"
sys.path.insert(0, str(STANDARDS))
from colors import color_map, genus_order, control_color_map, control_order  # noqa
print(f"REPO_ROOT = {REPO_ROOT}")
print(f"OUTPUTS   = {OUTPUTS}")

# %% [markdown]
# ## Reference inputs
#
# Inputs depend on which figure you are building. See the matching .py script for the canonical paths.
